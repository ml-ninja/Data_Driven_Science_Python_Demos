# %%
# !pip install -U scikit-image

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
plt.rcParams['figure.figsize'] = [8,8]
plt.rcParams.update({'font.size': 18})

n = 1000
q = int(n/4)
X = np.zeros((n,n))
X[(q-1):(3*q),(q-1):(3*q)] = 1

plt.imshow(X)
plt.set_cmap('gray')
plt.axis('on')
plt.title('Unrotated Matrix')
plt.show()

# %%
# skimage.transform.rotate
from skimage import transform

X_rot = transform.rotate(X,10)
X_rot[np.nonzero(X_rot)] = 1

plt.imshow(X_rot)
plt.set_cmap('gray')
plt.axis('off')
plt.title('Rotated Matrix')
plt.show()

# %%
U, S, VT = np.linalg.svd(X,full_matrices=0)
print('S: ', S[:10])
# print('U: ', U[:, 0:1])

plt.semilogy(S,'-o',color='k')
plt.ylim((10**(-16),10**(4)+1))
plt.yticks(np.power(10,np.arange(-16,4,4, dtype=float)))
plt.xticks(np.arange(0,1000,250))
plt.grid()
plt.title('Unrotated Matrix: Spectrum')
plt.show()
# Out:
# S:  [5.01000000e+02 4.08916160e-12 3.54340071e-12 2.20529291e-12
#  1.91346439e-12 1.69796091e-12 6.72982089e-13 1.77756359e-13
#  6.63194999e-14 5.00099712e-14]

# %%
U_rot, S_rot, VT_rot = np.linalg.svd(X_rot,full_matrices=0)

plt.semilogy(S_rot,'-o',color='k')
plt.ylim((10**(-16),10**(4)+1))
plt.yticks(np.power(10,np.arange(-16,4,4, dtype=float)))
plt.xticks(np.arange(0,1000,250))
plt.grid()
plt.title('Rotated Matrix: Spectrum')
plt.show()
